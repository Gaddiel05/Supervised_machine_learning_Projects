# %% [markdown]
# # Random Forest - Regression
# ## Plus: An Additional Analysis of Various Regression Methods!
#
# ## The Data
#
# We just got hired by a tunnel boring company which uses X-rays in an attempt to know rock density, ideally this will allow them to switch out boring heads on their equipment before having to mine through the rock!
#
# They have given us some lab test results of signal strength returned in nHz to their sensors for various rock density types tested. You will notice it has almost a sine wave like relationship, where signal strength oscillates based off the density.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/rock_density_xray.csv")

# %%
df.head()
# Out:
#    Rebound Signal Strength nHz  Rock Density kg/m3
# 0                    72.945124            2.456548
# 1                    14.229877            2.601719
# 2                    36.597334            1.967004
# 3                     9.578899            2.300439
# 4                    21.765897            2.452374

# %%
df.columns=['Signal',"Density"]

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.scatterplot(x='Signal',y='Density',data=df)
# Out:
# <Axes: xlabel='Signal', ylabel='Density'>

# %% [markdown]
# ## Splitting the Data
#
# Let's split the data in order to be able to have a Test set for performance metric evaluation.

# %%
X = df['Signal'].values.reshape(-1,1)  
y = df['Density']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr_preds = lr_model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test,lr_preds))
# Out:
# 0.2570051996584629

# %%
y.mean()
# Out:
# 2.225062949323796

# %% [markdown]
# What does the fit look like?

# %%
signal_range = np.arange(0,100)

# %%
lr_output = lr_model.predict(signal_range.reshape(-1,1))

# %%
plt.figure(figsize=(10,6),dpi=200)
sns.scatterplot(x='Signal',y='Density',data=df,color='black')
plt.plot(signal_range,lr_output, color='red')

# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Attempting with a Polynomial Regression Model
#
# Let's explore why our standard regression approach of a polynomial could be difficult to fit here, keep in mind, we're in a fortunate situation where we can easily visualize results of y vs x.

# %% [markdown]
# ## Function to Help Run Models

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
def run_model(model,X_train,y_train,X_test,y_test):
    
    # Fit Model
    model.fit(X_train,y_train)
    
    # Get Metrics
    preds = model.predict(X_test)
    
    rmse = np.sqrt(mean_squared_error(y_test,preds))
    print(f'RMSE : {rmse}')
    
    # Plot results
    signal_range = np.arange(0,100)
    output = model.predict(signal_range.reshape(-1,1))
    
    plt.figure(figsize=(10,6),dpi=150)
    sns.scatterplot(x='Signal',y='Density',data=df,color='black')
    plt.plot(signal_range,output,color='red')

# %%
run_model(model,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.2570051996584629

# %% [markdown]
# ## Pipeline for Poly Orders

# %%
from sklearn.pipeline import make_pipeline

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pipe = make_pipeline(PolynomialFeatures(2),LinearRegression())

# %%
run_model(pipe,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.28173095637255463

# %% [markdown]
# ## Comparing Various Polynomial Orders

# %%
pipe = make_pipeline(PolynomialFeatures(4),LinearRegression())
run_model(pipe,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.14588633397625778

# %%
pipe = make_pipeline(PolynomialFeatures(10),LinearRegression())
run_model(pipe,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.14034142046390416

# %% [markdown]
# ## KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
preds = {}
k_values = [1,5,10]

for n in k_values:  
    model = KNeighborsRegressor(n_neighbors=n)
    run_model(model,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.1523487028635337
# RMSE : 0.13730685016923647
# RMSE : 0.13277855732740926

# %% [markdown]
# ## Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()
run_model(model,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.1523487028635337

# %%
model.get_n_leaves()
# Out:
# 270

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(model)
# Out:
# [Text(0.35031591086278585, 0.9761904761904762, 'x[0] <= 27.551\nsquared_error = 0.102\nsamples = 270\nvalue = 2.22'),
#  Text(0.08917824707298391, 0.9285714285714286, 'x[0] <= 3.966\nsquared_error = 0.032\nsamples = 71\nvalue = 2.44'),
#  Text(0.015756647335594703, 0.8809523809523809, 'x[0] <= 1.356\nsquared_error = 0.018\nsamples = 11\nvalue = 2.196'),
#  Text(0.007002954371375424, 0.8333333333333334, 'x[0] <= 0.992\nsquared_error = 0.004\nsamples = 2\nvalue = 2.048'),
#  Text(0.003501477185687712, 0.7857142857142857, 'squared_error = 0.0\nsamples = 1\nvalue = 2.113'),
#  Text(0.010504431557063137, 0.7857142857142857, 'squared_error = -0.0\nsamples = 1\nvalue = 1.982'),
#  Text(0.024510340299813985, 0.8333333333333334, 'x[0] <= 3.216\nsquared_error = 0.015\nsamples = 9\nvalue = 2.229'),
#  Text(0.01750738592843856, 0.7857142857142857, 'x[0] <= 1.545\nsquared_error = 0.013\nsamples = 7\nvalue = 2.268'),
#  Text(0.014005908742750848, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 2.405'),
#  Text(0.021008863114126274, 0.7380952380952381, 'x[0] <= 2.14\nsquared_error = 0.011\nsamples = 6\nvalue = 2.245'),
#  Text(0.014005908742750848, 0.6904761904761905, 'x[0] <= 1.794\nsquared_error = 0.007\nsamples = 3\nvalue = 2.189'),
#  Text(0.010504431557063137, 0.6428571428571429, 'x[0] <= 1.693\nsquared_error = 0.001\nsamples = 2\nvalue = 2.246'),
#  Text(0.007002954371375424, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.222'),
#  Text(0.014005908742750848, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.271'),
#  Text(0.01750738592843856, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.073'),
#  Text(0.028011817485501696, 0.6904761904761905, 'x[0] <= 2.732\nsquared_error = 0.009\nsamples = 3\nvalue = 2.302'),
#  Text(0.024510340299813985, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.427'),
#  Text(0.03151329467118941, 0.6428571428571429, 'x[0] <= 3.064\nsquared_error = 0.001\nsamples = 2\nvalue = 2.239'),
#  Text(0.028011817485501696, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.206'),
#  Text(0.03501477185687712, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.273'),
#  Text(0.03151329467118941, 0.7857142857142857, 'x[0] <= 3.361\nsquared_error = 0.0\nsamples = 2\nvalue = 2.094'),
#  Text(0.028011817485501696, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 2.09'),
#  Text(0.03501477185687712, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 2.097'),
#  Text(0.16259984681037312, 0.8809523809523809, 'x[0] <= 20.259\nsquared_error = 0.022\nsamples = 60\nvalue = 2.485'),
#  Text(0.10548200021884233, 0.8333333333333334, 'x[0] <= 9.735\nsquared_error = 0.017\nsamples = 45\nvalue = 2.521'),
#  Text(0.07878323667797352, 0.7857142857142857, 'x[0] <= 8.944\nsquared_error = 0.012\nsamples = 12\nvalue = 2.416'),
#  Text(0.06652806652806653, 0.7380952380952381, 'x[0] <= 7.93\nsquared_error = 0.011\nsamples = 10\nvalue = 2.441'),
#  Text(0.05252215778531568, 0.6904761904761905, 'x[0] <= 7.238\nsquared_error = 0.011\nsamples = 6\nvalue = 2.471'),
#  Text(0.04551920341394026, 0.6428571428571429, 'x[0] <= 4.729\nsquared_error = 0.001\nsamples = 4\nvalue = 2.398'),
#  Text(0.04201772622825255, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.451'),
#  Text(0.04902068059962797, 0.5952380952380952, 'x[0] <= 6.19\nsquared_error = 0.0\nsamples = 3\nvalue = 2.38'),
#  Text(0.04551920341394026, 0.5476190476190477, 'x[0] <= 5.092\nsquared_error = 0.0\nsamples = 2\nvalue = 2.386'),
#  Text(0.04201772622825255, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.387'),
#  Text(0.04902068059962797, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 2.386'),
#  Text(0.05252215778531568, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.367'),
#  Text(0.0595251121566911, 0.6428571428571429, 'x[0] <= 7.58\nsquared_error = 0.0\nsamples = 2\nvalue = 2.618'),
#  Text(0.05602363497100339, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.618'),
#  Text(0.06302658934237881, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.617'),
#  Text(0.08053397527081738, 0.6904761904761905, 'x[0] <= 8.591\nsquared_error = 0.006\nsamples = 4\nvalue = 2.396'),
#  Text(0.07353102089944195, 0.6428571428571429, 'x[0] <= 8.297\nsquared_error = 0.0\nsamples = 2\nvalue = 2.316'),
#  Text(0.07002954371375424, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.32'),
#  Text(0.07703249808512966, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 2.313'),
#  Text(0.0875369296421928, 0.6428571428571429, 'x[0] <= 8.732\nsquared_error = 0.0\nsamples = 2\nvalue = 2.476'),
#  Text(0.0840354524565051, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.492'),
#  Text(0.09103840682788052, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.459'),
#  Text(0.09103840682788052, 0.7380952380952381, 'x[0] <= 9.337\nsquared_error = 0.0\nsamples = 2\nvalue = 2.292'),
#  Text(0.0875369296421928, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.284'),
#  Text(0.09453988401356822, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.3'),
#  Text(0.13218076375971113, 0.7857142857142857, 'x[0] <= 16.111\nsquared_error = 0.014\nsamples = 33\nvalue = 2.559'),
#  Text(0.10854579275631908, 0.7380952380952381, 'x[0] <= 15.283\nsquared_error = 0.015\nsamples = 21\nvalue = 2.585'),
#  Text(0.10154283838494364, 0.6904761904761905, 'x[0] <= 10.211\nsquared_error = 0.014\nsamples = 19\nvalue = 2.571'),
#  Text(0.09804136119925594, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.699'),
#  Text(0.10504431557063136, 0.6428571428571429, 'x[0] <= 10.903\nsquared_error = 0.014\nsamples = 18\nvalue = 2.564'),
#  Text(0.10154283838494364, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.302'),
#  Text(0.10854579275631908, 0.5952380952380952, 'x[0] <= 12.486\nsquared_error = 0.01\nsamples = 17\nvalue = 2.579'),
#  Text(0.09453988401356822, 0.5476190476190477, 'x[0] <= 11.891\nsquared_error = 0.006\nsamples = 5\nvalue = 2.643'),
#  Text(0.0875369296421928, 0.5, 'x[0] <= 11.633\nsquared_error = 0.006\nsamples = 3\nvalue = 2.608'),
#  Text(0.0840354524565051, 0.4523809523809524, 'x[0] <= 11.421\nsquared_error = 0.0\nsamples = 2\nvalue = 2.665'),
#  Text(0.08053397527081738, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.668'),
#  Text(0.0875369296421928, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.661'),
#  Text(0.09103840682788052, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.494'),
#  Text(0.10154283838494364, 0.5, 'x[0] <= 12.096\nsquared_error = 0.0\nsamples = 2\nvalue = 2.696'),
#  Text(0.09804136119925594, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.676'),
#  Text(0.10504431557063136, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 2.716'),
#  Text(0.12255170149906992, 0.5476190476190477, 'x[0] <= 13.147\nsquared_error = 0.01\nsamples = 12\nvalue = 2.553'),
#  Text(0.1155487471276945, 0.5, 'x[0] <= 12.913\nsquared_error = 0.005\nsamples = 3\nvalue = 2.494'),
#  Text(0.11204726994200678, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.576'),
#  Text(0.1190502243133822, 0.4523809523809524, 'x[0] <= 13.032\nsquared_error = 0.002\nsamples = 2\nvalue = 2.453'),
#  Text(0.1155487471276945, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.404'),
#  Text(0.12255170149906992, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.501'),
#  Text(0.12955465587044535, 0.5, 'x[0] <= 13.441\nsquared_error = 0.01\nsamples = 9\nvalue = 2.572'),
#  Text(0.12605317868475763, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.733'),
#  Text(0.13305613305613306, 0.4523809523809524, 'x[0] <= 13.912\nsquared_error = 0.007\nsamples = 8\nvalue = 2.552'),
#  Text(0.12955465587044535, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.434'),
#  Text(0.13655761024182078, 0.40476190476190477, 'x[0] <= 15.196\nsquared_error = 0.006\nsamples = 7\nvalue = 2.569'),
#  Text(0.13305613305613306, 0.35714285714285715, 'x[0] <= 14.183\nsquared_error = 0.004\nsamples = 6\nvalue = 2.59'),
#  Text(0.12955465587044535, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.686'),
#  Text(0.13655761024182078, 0.30952380952380953, 'x[0] <= 15.098\nsquared_error = 0.003\nsamples = 5\nvalue = 2.57'),
#  Text(0.13305613305613306, 0.2619047619047619, 'x[0] <= 14.265\nsquared_error = 0.001\nsamples = 4\nvalue = 2.552'),
#  Text(0.12955465587044535, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 2.602'),
#  Text(0.13655761024182078, 0.21428571428571427, 'x[0] <= 14.68\nsquared_error = 0.001\nsamples = 3\nvalue = 2.535'),
#  Text(0.13305613305613306, 0.16666666666666666, 'x[0] <= 14.313\nsquared_error = 0.001\nsamples = 2\nvalue = 2.55'),
#  Text(0.12955465587044535, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 2.528'),
#  Text(0.13655761024182078, 0.11904761904761904, 'squared_error = 0.0\nsamples = 1\nvalue = 2.573'),
#  Text(0.14005908742750847, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.504'),
#  Text(0.14005908742750847, 0.2619047619047619, 'squared_error = -0.0\nsamples = 1\nvalue = 2.645'),
#  Text(0.14005908742750847, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 2.445'),
#  Text(0.1155487471276945, 0.6904761904761905, 'x[0] <= 15.6\nsquared_error = 0.001\nsamples = 2\nvalue = 2.718'),
#  Text(0.11204726994200678, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.686'),
#  Text(0.1190502243133822, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.75'),
#  Text(0.15581573476310318, 0.7380952380952381, 'x[0] <= 19.449\nsquared_error = 0.009\nsamples = 12\nvalue = 2.512'),
#  Text(0.14881278039172777, 0.6904761904761905, 'x[0] <= 18.739\nsquared_error = 0.006\nsamples = 9\nvalue = 2.483'),
#  Text(0.14531130320604005, 0.6428571428571429, 'x[0] <= 16.611\nsquared_error = 0.006\nsamples = 8\nvalue = 2.495'),
#  Text(0.14180982602035233, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.391'),
#  Text(0.14881278039172777, 0.5952380952380952, 'x[0] <= 17.395\nsquared_error = 0.005\nsamples = 7\nvalue = 2.51'),
#  Text(0.14005908742750847, 0.5476190476190477, 'x[0] <= 17.095\nsquared_error = 0.0\nsamples = 2\nvalue = 2.569'),
#  Text(0.13655761024182078, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.553'),
#  Text(0.1435605646131962, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 2.586'),
#  Text(0.15756647335594703, 0.5476190476190477, 'x[0] <= 17.732\nsquared_error = 0.005\nsamples = 5\nvalue = 2.486'),
#  Text(0.15056351898457163, 0.5, 'x[0] <= 17.482\nsquared_error = 0.005\nsamples = 2\nvalue = 2.431'),
#  Text(0.1470620417988839, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.499'),
#  Text(0.15406499617025932, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.364'),
#  Text(0.16456942772732247, 0.5, 'x[0] <= 18.004\nsquared_error = 0.001\nsamples = 3\nvalue = 2.522'),
#  Text(0.16106795054163475, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.561'),
#  Text(0.1680709049130102, 0.4523809523809524, 'x[0] <= 18.236\nsquared_error = 0.001\nsamples = 2\nvalue = 2.503'),
#  Text(0.16456942772732247, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.476'),
#  Text(0.17157238209869788, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.529'),
#  Text(0.15231425757741548, 0.6428571428571429, 'squared_error = -0.0\nsamples = 1\nvalue = 2.384'),
#  Text(0.1628186891344786, 0.6904761904761905, 'x[0] <= 19.985\nsquared_error = 0.007\nsamples = 3\nvalue = 2.602'),
#  Text(0.1593172119487909, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.704'),
#  Text(0.16632016632016633, 0.6428571428571429, 'x[0] <= 20.134\nsquared_error = 0.002\nsamples = 2\nvalue = 2.55'),
#  Text(0.1628186891344786, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.6'),
#  Text(0.16982164350585402, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.501'),
#  Text(0.21971769340190392, 0.8333333333333334, 'x[0] <= 25.396\nsquared_error = 0.019\nsamples = 15\nvalue = 2.378'),
#  Text(0.20308567676988729, 0.7857142857142857, 'x[0] <= 23.644\nsquared_error = 0.02\nsamples = 10\nvalue = 2.405'),
#  Text(0.1908305066199803, 0.7380952380952381, 'x[0] <= 22.076\nsquared_error = 0.012\nsamples = 6\nvalue = 2.345'),
#  Text(0.1838275522486049, 0.6904761904761905, 'x[0] <= 20.723\nsquared_error = 0.006\nsamples = 3\nvalue = 2.437'),
#  Text(0.18032607506291717, 0.6428571428571429, 'x[0] <= 20.438\nsquared_error = 0.001\nsamples = 2\nvalue = 2.384'),
#  Text(0.17682459787722946, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.357'),
#  Text(0.1838275522486049, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.411'),
#  Text(0.18732902943429258, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.544'),
#  Text(0.19783346099135574, 0.6904761904761905, 'x[0] <= 23.482\nsquared_error = 0.001\nsamples = 3\nvalue = 2.253'),
#  Text(0.19433198380566802, 0.6428571428571429, 'x[0] <= 23.285\nsquared_error = 0.0\nsamples = 2\nvalue = 2.269'),
#  Text(0.1908305066199803, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.262'),
#  Text(0.19783346099135574, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 2.276'),
#  Text(0.20133493817704343, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.22'),
#  Text(0.2153408469197943, 0.7380952380952381, 'x[0] <= 24.453\nsquared_error = 0.019\nsamples = 4\nvalue = 2.495'),
#  Text(0.21183936973410658, 0.6904761904761905, 'x[0] <= 24.013\nsquared_error = 0.02\nsamples = 3\nvalue = 2.458'),
#  Text(0.20833789254841886, 0.6428571428571429, 'x[0] <= 23.81\nsquared_error = 0.0\nsamples = 2\nvalue = 2.559'),
#  Text(0.20483641536273114, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.545'),
#  Text(0.21183936973410658, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.572'),
#  Text(0.2153408469197943, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.256'),
#  Text(0.218842324105482, 0.6904761904761905, 'squared_error = -0.0\nsamples = 1\nvalue = 2.606'),
#  Text(0.23634971003392055, 0.7857142857142857, 'x[0] <= 26.226\nsquared_error = 0.013\nsamples = 5\nvalue = 2.324'),
#  Text(0.22934675566254514, 0.7380952380952381, 'x[0] <= 25.986\nsquared_error = 0.004\nsamples = 2\nvalue = 2.203'),
#  Text(0.22584527847685743, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.266'),
#  Text(0.23284823284823286, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.14'),
#  Text(0.243352664405296, 0.7380952380952381, 'x[0] <= 26.59\nsquared_error = 0.002\nsamples = 3\nvalue = 2.405'),
#  Text(0.23985118721960827, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.446'),
#  Text(0.2468541415909837, 0.6904761904761905, 'x[0] <= 27.049\nsquared_error = 0.002\nsamples = 2\nvalue = 2.385'),
#  Text(0.243352664405296, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.342'),
#  Text(0.2503556187766714, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.427'),
#  Text(0.6114535746525878, 0.9285714285714286, 'x[0] <= 62.664\nsquared_error = 0.104\nsamples = 199\nvalue = 2.142'),
#  Text(0.3836647882700514, 0.8809523809523809, 'x[0] <= 34.367\nsquared_error = 0.048\nsamples = 95\nvalue = 1.886'),
#  Text(0.27924280555859504, 0.8333333333333334, 'x[0] <= 30.626\nsquared_error = 0.02\nsamples = 18\nvalue = 2.167'),
#  Text(0.26436152751942227, 0.7857142857142857, 'x[0] <= 29.191\nsquared_error = 0.007\nsamples = 5\nvalue = 2.275'),
#  Text(0.25735857314804683, 0.7380952380952381, 'x[0] <= 28.207\nsquared_error = 0.0\nsamples = 2\nvalue = 2.181'),
#  Text(0.2538570959623591, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.188'),
#  Text(0.26086005033373455, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.175'),
#  Text(0.2713644818907977, 0.7380952380952381, 'x[0] <= 29.743\nsquared_error = 0.001\nsamples = 3\nvalue = 2.337'),
#  Text(0.26786300470511, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.286'),
#  Text(0.27486595907648537, 0.6904761904761905, 'x[0] <= 30.158\nsquared_error = 0.0\nsamples = 2\nvalue = 2.363'),
#  Text(0.2713644818907977, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.379'),
#  Text(0.2783674362621731, 0.6428571428571429, 'squared_error = -0.0\nsamples = 1\nvalue = 2.346'),
#  Text(0.2941240835977678, 0.7857142857142857, 'x[0] <= 31.098\nsquared_error = 0.019\nsamples = 13\nvalue = 2.125'),
#  Text(0.2906226064120801, 0.7380952380952381, 'squared_error = 0.0\nsamples = 1\nvalue = 1.992'),
#  Text(0.29762556078345553, 0.7380952380952381, 'x[0] <= 31.756\nsquared_error = 0.019\nsamples = 12\nvalue = 2.136'),
#  Text(0.28887186781923624, 0.6904761904761905, 'x[0] <= 31.526\nsquared_error = 0.004\nsamples = 2\nvalue = 2.255'),
#  Text(0.2853703906335485, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.194'),
#  Text(0.29237334500492396, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.315'),
#  Text(0.3063792537476748, 0.6904761904761905, 'x[0] <= 33.319\nsquared_error = 0.019\nsamples = 10\nvalue = 2.113'),
#  Text(0.2993762993762994, 0.6428571428571429, 'x[0] <= 32.743\nsquared_error = 0.021\nsamples = 8\nvalue = 2.087'),
#  Text(0.2958748221906117, 0.5952380952380952, 'x[0] <= 32.595\nsquared_error = 0.02\nsamples = 7\nvalue = 2.109'),
#  Text(0.29237334500492396, 0.5476190476190477, 'x[0] <= 32.518\nsquared_error = 0.018\nsamples = 6\nvalue = 2.082'),
#  Text(0.28887186781923624, 0.5, 'x[0] <= 32.345\nsquared_error = 0.014\nsamples = 5\nvalue = 2.118'),
#  Text(0.2853703906335485, 0.4523809523809524, 'x[0] <= 31.971\nsquared_error = 0.01\nsamples = 4\nvalue = 2.079'),
#  Text(0.2818689134478608, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.978'),
#  Text(0.28887186781923624, 0.40476190476190477, 'x[0] <= 32.015\nsquared_error = 0.009\nsamples = 3\nvalue = 2.112'),
#  Text(0.2853703906335485, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 2.232'),
#  Text(0.29237334500492396, 0.35714285714285715, 'x[0] <= 32.1\nsquared_error = 0.003\nsamples = 2\nvalue = 2.053'),
#  Text(0.28887186781923624, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.001'),
#  Text(0.2958748221906117, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.105'),
#  Text(0.29237334500492396, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.275'),
#  Text(0.2958748221906117, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 1.903'),
#  Text(0.2993762993762994, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.27'),
#  Text(0.3028777765619871, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.935'),
#  Text(0.3133822081190502, 0.6428571428571429, 'x[0] <= 33.919\nsquared_error = 0.0\nsamples = 2\nvalue = 2.215'),
#  Text(0.3098807309333625, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.215'),
#  Text(0.3168836853047379, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.215'),
#  Text(0.4880867709815078, 0.8333333333333334, 'x[0] <= 55.7\nsquared_error = 0.032\nsamples = 77\nvalue = 1.82'),
#  Text(0.41287339971550496, 0.7857142857142857, 'x[0] <= 38.704\nsquared_error = 0.023\nsamples = 60\nvalue = 1.765'),
#  Text(0.3545245650508808, 0.7380952380952381, 'x[0] <= 36.687\nsquared_error = 0.017\nsamples = 14\nvalue = 1.897'),
#  Text(0.3343910712331765, 0.6904761904761905, 'x[0] <= 35.041\nsquared_error = 0.014\nsamples = 7\nvalue = 1.953'),
#  Text(0.3273881168618011, 0.6428571428571429, 'x[0] <= 34.868\nsquared_error = 0.0\nsamples = 2\nvalue = 1.801'),
#  Text(0.32388663967611336, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.808'),
#  Text(0.3308895940474888, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.794'),
#  Text(0.3413940256045519, 0.6428571428571429, 'x[0] <= 35.542\nsquared_error = 0.006\nsamples = 5\nvalue = 2.013'),
#  Text(0.33789254841886424, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.168'),
#  Text(0.3448955027902396, 0.5952380952380952, 'x[0] <= 36.087\nsquared_error = 0.001\nsamples = 4\nvalue = 1.974'),
#  Text(0.3413940256045519, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.942'),
#  Text(0.34839697997592733, 0.5476190476190477, 'x[0] <= 36.262\nsquared_error = 0.0\nsamples = 3\nvalue = 1.985'),
#  Text(0.3448955027902396, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.012'),
#  Text(0.35189845716161505, 0.5, 'x[0] <= 36.49\nsquared_error = 0.0\nsamples = 2\nvalue = 1.972'),
#  Text(0.34839697997592733, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 1.976'),
#  Text(0.35539993434730277, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 1.967'),
#  Text(0.37465805886858516, 0.6904761904761905, 'x[0] <= 37.957\nsquared_error = 0.014\nsamples = 7\nvalue = 1.842'),
#  Text(0.3659043659043659, 0.6428571428571429, 'x[0] <= 37.313\nsquared_error = 0.003\nsamples = 5\nvalue = 1.775'),
#  Text(0.3589014115329905, 0.5952380952380952, 'x[0] <= 36.894\nsquared_error = 0.0\nsamples = 2\nvalue = 1.816'),
#  Text(0.35539993434730277, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.812'),
#  Text(0.3624028887186782, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 1.82'),
#  Text(0.3729073202757413, 0.5952380952380952, 'x[0] <= 37.665\nsquared_error = 0.003\nsamples = 3\nvalue = 1.748'),
#  Text(0.36940584309005364, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.668'),
#  Text(0.376408797461429, 0.5476190476190477, 'x[0] <= 37.804\nsquared_error = 0.0\nsamples = 2\nvalue = 1.787'),
#  Text(0.3729073202757413, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.797'),
#  Text(0.37991027464711674, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.777'),
#  Text(0.38341175183280446, 0.6428571428571429, 'x[0] <= 38.224\nsquared_error = 0.001\nsamples = 2\nvalue = 2.01'),
#  Text(0.37991027464711674, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.044'),
#  Text(0.3869132290184922, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 1.975'),
#  Text(0.4712222343801291, 0.7380952380952381, 'x[0] <= 51.17\nsquared_error = 0.018\nsamples = 46\nvalue = 1.725'),
#  Text(0.4356056461319619, 0.6904761904761905, 'x[0] <= 39.995\nsquared_error = 0.018\nsamples = 34\nvalue = 1.701'),
#  Text(0.4096728307254623, 0.6428571428571429, 'x[0] <= 39.504\nsquared_error = 0.002\nsamples = 3\nvalue = 1.803'),
#  Text(0.40617135353977457, 0.5952380952380952, 'x[0] <= 39.146\nsquared_error = 0.001\nsamples = 2\nvalue = 1.775'),
#  Text(0.40266987635408685, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.807'),
#  Text(0.4096728307254623, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.744'),
#  Text(0.41317430791115, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 1.86'),
#  Text(0.46153846153846156, 0.6428571428571429, 'x[0] <= 50.603\nsquared_error = 0.019\nsamples = 31\nvalue = 1.692'),
#  Text(0.4407484407484408, 0.5952380952380952, 'x[0] <= 49.47\nsquared_error = 0.019\nsamples = 28\nvalue = 1.701'),
#  Text(0.4166757850968377, 0.5476190476190477, 'x[0] <= 47.728\nsquared_error = 0.018\nsamples = 25\nvalue = 1.685'),
#  Text(0.38953933690775794, 0.5, 'x[0] <= 45.174\nsquared_error = 0.02\nsamples = 21\nvalue = 1.703'),
#  Text(0.3624028887186782, 0.4523809523809524, 'x[0] <= 43.818\nsquared_error = 0.017\nsamples = 12\nvalue = 1.657'),
#  Text(0.35102308786519315, 0.40476190476190477, 'x[0] <= 43.358\nsquared_error = 0.015\nsamples = 8\nvalue = 1.711'),
#  Text(0.34752161067950543, 0.35714285714285715, 'x[0] <= 42.638\nsquared_error = 0.01\nsamples = 7\nvalue = 1.68'),
#  Text(0.33876791771528614, 0.30952380952380953, 'x[0] <= 41.38\nsquared_error = 0.004\nsamples = 5\nvalue = 1.731'),
#  Text(0.3317649633439107, 0.2619047619047619, 'x[0] <= 40.432\nsquared_error = 0.003\nsamples = 3\nvalue = 1.688'),
#  Text(0.328263486158223, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 1.643'),
#  Text(0.3352664405295984, 0.21428571428571427, 'x[0] <= 40.839\nsquared_error = 0.003\nsamples = 2\nvalue = 1.711'),
#  Text(0.3317649633439107, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 1.763'),
#  Text(0.33876791771528614, 0.16666666666666666, 'squared_error = -0.0\nsamples = 1\nvalue = 1.658'),
#  Text(0.3457708720866616, 0.2619047619047619, 'x[0] <= 42.026\nsquared_error = 0.0\nsamples = 2\nvalue = 1.794'),
#  Text(0.34226939490097386, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 1.794'),
#  Text(0.3492723492723493, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 1.795'),
#  Text(0.3562753036437247, 0.30952380952380953, 'x[0] <= 42.946\nsquared_error = 0.0\nsamples = 2\nvalue = 1.552'),
#  Text(0.352773826458037, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 1.569'),
#  Text(0.3597767808294124, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 1.535'),
#  Text(0.3545245650508808, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 1.931'),
#  Text(0.37378268957216326, 0.40476190476190477, 'x[0] <= 44.602\nsquared_error = 0.002\nsamples = 4\nvalue = 1.55'),
#  Text(0.3667797352007878, 0.35714285714285715, 'x[0] <= 44.067\nsquared_error = 0.004\nsamples = 2\nvalue = 1.575'),
#  Text(0.3632782580151001, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.514'),
#  Text(0.37028121238647554, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.635'),
#  Text(0.3807856439435387, 0.35714285714285715, 'x[0] <= 45.042\nsquared_error = 0.0\nsamples = 2\nvalue = 1.525'),
#  Text(0.377284166757851, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.518'),
#  Text(0.3842871211292264, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.531'),
#  Text(0.4166757850968377, 0.4523809523809524, 'x[0] <= 47.457\nsquared_error = 0.017\nsamples = 9\nvalue = 1.763'),
#  Text(0.40704672283619653, 0.40476190476190477, 'x[0] <= 46.561\nsquared_error = 0.019\nsamples = 7\nvalue = 1.788'),
#  Text(0.39829302987197723, 0.35714285714285715, 'x[0] <= 45.527\nsquared_error = 0.02\nsamples = 5\nvalue = 1.745'),
#  Text(0.3912900755006018, 0.30952380952380953, 'x[0] <= 45.37\nsquared_error = 0.007\nsamples = 3\nvalue = 1.82'),
#  Text(0.3877885983149141, 0.2619047619047619, 'x[0] <= 45.305\nsquared_error = 0.006\nsamples = 2\nvalue = 1.781'),
#  Text(0.3842871211292264, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 1.861'),
#  Text(0.3912900755006018, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 1.701'),
#  Text(0.3947915526862895, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 1.899'),
#  Text(0.40529598424335267, 0.30952380952380953, 'x[0] <= 45.816\nsquared_error = 0.017\nsamples = 2\nvalue = 1.632'),
#  Text(0.40179450705766495, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.4087974614290404, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 1.764'),
#  Text(0.4158004158004158, 0.35714285714285715, 'x[0] <= 47.3\nsquared_error = 0.0\nsamples = 2\nvalue = 1.895'),
#  Text(0.4122989386147281, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.911'),
#  Text(0.4193018929861035, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 1.879'),
#  Text(0.4263048473574789, 0.40476190476190477, 'x[0] <= 47.591\nsquared_error = 0.0\nsamples = 2\nvalue = 1.678'),
#  Text(0.4228033701717912, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 1.661'),
#  Text(0.42980632454316664, 0.35714285714285715, 'squared_error = -0.0\nsamples = 1\nvalue = 1.695'),
#  Text(0.4438122332859175, 0.5, 'x[0] <= 48.357\nsquared_error = 0.002\nsamples = 4\nvalue = 1.594'),
#  Text(0.4368092789145421, 0.4523809523809524, 'x[0] <= 47.85\nsquared_error = 0.002\nsamples = 2\nvalue = 1.568'),
#  Text(0.43330780172885436, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.61'),
#  Text(0.4403107561002298, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.526'),
#  Text(0.4508151876572929, 0.4523809523809524, 'x[0] <= 49.088\nsquared_error = 0.0\nsamples = 2\nvalue = 1.62'),
#  Text(0.44731371047160523, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.618'),
#  Text(0.4543166648429806, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 1.622'),
#  Text(0.46482109640004377, 0.5476190476190477, 'x[0] <= 50.324\nsquared_error = 0.007\nsamples = 3\nvalue = 1.835'),
#  Text(0.46131961921435605, 0.5, 'x[0] <= 49.824\nsquared_error = 0.0\nsamples = 2\nvalue = 1.891'),
#  Text(0.45781814202866833, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 1.876'),
#  Text(0.46482109640004377, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 1.906'),
#  Text(0.4683225735857315, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.722'),
#  Text(0.48232848232848236, 0.5952380952380952, 'x[0] <= 50.997\nsquared_error = 0.003\nsamples = 3\nvalue = 1.601'),
#  Text(0.47882700514279464, 0.5476190476190477, 'x[0] <= 50.769\nsquared_error = 0.004\nsamples = 2\nvalue = 1.624'),
#  Text(0.4753255279571069, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.563'),
#  Text(0.48232848232848236, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.684'),
#  Text(0.48582995951417, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.556'),
#  Text(0.5068388226282963, 0.6904761904761905, 'x[0] <= 55.123\nsquared_error = 0.013\nsamples = 12\nvalue = 1.791'),
#  Text(0.4998358682569209, 0.6428571428571429, 'x[0] <= 54.986\nsquared_error = 0.009\nsamples = 10\nvalue = 1.822'),
#  Text(0.49633439107123317, 0.5952380952380952, 'x[0] <= 51.366\nsquared_error = 0.007\nsamples = 9\nvalue = 1.804'),
#  Text(0.49283291388554545, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.882'),
#  Text(0.4998358682569209, 0.5476190476190477, 'x[0] <= 51.812\nsquared_error = 0.007\nsamples = 8\nvalue = 1.794'),
#  Text(0.49633439107123317, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.67'),
#  Text(0.5033373454426086, 0.5, 'x[0] <= 54.806\nsquared_error = 0.005\nsamples = 7\nvalue = 1.812'),
#  Text(0.4998358682569209, 0.4523809523809524, 'x[0] <= 54.016\nsquared_error = 0.006\nsamples = 6\nvalue = 1.822'),
#  Text(0.49283291388554545, 0.40476190476190477, 'x[0] <= 53.583\nsquared_error = 0.005\nsamples = 3\nvalue = 1.784'),
#  Text(0.48933143669985774, 0.35714285714285715, 'x[0] <= 52.687\nsquared_error = 0.0\nsamples = 2\nvalue = 1.832'),
#  Text(0.48582995951417, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.848'),
#  Text(0.49283291388554545, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.817'),
#  Text(0.49633439107123317, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 1.688'),
#  Text(0.5068388226282963, 0.40476190476190477, 'x[0] <= 54.181\nsquared_error = 0.004\nsamples = 3\nvalue = 1.86'),
#  Text(0.5033373454426086, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 1.921'),
#  Text(0.510340299813984, 0.35714285714285715, 'x[0] <= 54.438\nsquared_error = 0.002\nsamples = 2\nvalue = 1.829'),
#  Text(0.5068388226282963, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.779'),
#  Text(0.5138417769996717, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 1.879'),
#  Text(0.5068388226282963, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 1.748'),
#  Text(0.5033373454426086, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 1.99'),
#  Text(0.5138417769996717, 0.6428571428571429, 'x[0] <= 55.421\nsquared_error = 0.0\nsamples = 2\nvalue = 1.634'),
#  Text(0.510340299813984, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.635'),
#  Text(0.5173432541853594, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 1.633'),
#  Text(0.5633001422475107, 0.7857142857142857, 'x[0] <= 59.49\nsquared_error = 0.015\nsamples = 17\nvalue = 2.016'),
#  Text(0.5392274865959077, 0.7380952380952381, 'x[0] <= 56.853\nsquared_error = 0.009\nsamples = 10\nvalue = 1.976'),
#  Text(0.5243462085567349, 0.6904761904761905, 'x[0] <= 56.013\nsquared_error = 0.013\nsamples = 3\nvalue = 1.927'),
#  Text(0.5208447313710471, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.053'),
#  Text(0.5278476857424226, 0.6428571428571429, 'x[0] <= 56.287\nsquared_error = 0.007\nsamples = 2\nvalue = 1.864'),
#  Text(0.5243462085567349, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.779'),
#  Text(0.5313491629281103, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.949'),
#  Text(0.5541087646350804, 0.6904761904761905, 'x[0] <= 58.598\nsquared_error = 0.006\nsamples = 7\nvalue = 1.996'),
#  Text(0.5453550716708612, 0.6428571428571429, 'x[0] <= 58.071\nsquared_error = 0.005\nsamples = 4\nvalue = 2.036'),
#  Text(0.5383521172994857, 0.5952380952380952, 'x[0] <= 57.562\nsquared_error = 0.002\nsamples = 2\nvalue = 2.002'),
#  Text(0.534850640113798, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.047'),
#  Text(0.5418535944851735, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 1.957'),
#  Text(0.5523580260422366, 0.5952380952380952, 'x[0] <= 58.495\nsquared_error = 0.005\nsamples = 2\nvalue = 2.07'),
#  Text(0.5488565488565489, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.14'),
#  Text(0.5558595032279243, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.5628624575992998, 0.6428571428571429, 'x[0] <= 58.808\nsquared_error = 0.002\nsamples = 3\nvalue = 1.944'),
#  Text(0.559360980413612, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.878'),
#  Text(0.5663639347849874, 0.5952380952380952, 'x[0] <= 59.045\nsquared_error = 0.0\nsamples = 2\nvalue = 1.976'),
#  Text(0.5628624575992998, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 1.957'),
#  Text(0.5698654119706751, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 1.995'),
#  Text(0.5873727978991137, 0.7380952380952381, 'x[0] <= 62.076\nsquared_error = 0.018\nsamples = 7\nvalue = 2.073'),
#  Text(0.583871320713426, 0.6904761904761905, 'x[0] <= 60.286\nsquared_error = 0.015\nsamples = 6\nvalue = 2.101'),
#  Text(0.5768683663420505, 0.6428571428571429, 'x[0] <= 59.994\nsquared_error = 0.003\nsamples = 2\nvalue = 2.16'),
#  Text(0.5733668891563628, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.109'),
#  Text(0.5803698435277382, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 2.212'),
#  Text(0.5908742750848014, 0.6428571428571429, 'x[0] <= 60.635\nsquared_error = 0.019\nsamples = 4\nvalue = 2.071'),
#  Text(0.5873727978991137, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 1.868'),
#  Text(0.5943757522704891, 0.5952380952380952, 'x[0] <= 61.015\nsquared_error = 0.006\nsamples = 3\nvalue = 2.139'),
#  Text(0.5908742750848014, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.244'),
#  Text(0.5978772294561768, 0.5476190476190477, 'x[0] <= 61.519\nsquared_error = 0.001\nsamples = 2\nvalue = 2.087'),
#  Text(0.5943757522704891, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.124'),
#  Text(0.6013787066418645, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 2.049'),
#  Text(0.5908742750848014, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 1.906'),
#  Text(0.8392423610351242, 0.8809523809523809, 'x[0] <= 90.235\nsquared_error = 0.04\nsamples = 104\nvalue = 2.376'),
#  Text(0.7266300333734544, 0.8333333333333334, 'x[0] <= 69.217\nsquared_error = 0.028\nsamples = 83\nvalue = 2.437'),
#  Text(0.6398949556844293, 0.7857142857142857, 'x[0] <= 64.966\nsquared_error = 0.008\nsamples = 20\nvalue = 2.246'),
#  Text(0.6223875697559909, 0.7380952380952381, 'x[0] <= 64.528\nsquared_error = 0.009\nsamples = 7\nvalue = 2.195'),
#  Text(0.6188860925703031, 0.6904761904761905, 'x[0] <= 63.735\nsquared_error = 0.007\nsamples = 6\nvalue = 2.218'),
#  Text(0.6118831381989277, 0.6428571428571429, 'x[0] <= 63.543\nsquared_error = 0.004\nsamples = 3\nvalue = 2.175'),
#  Text(0.60838166101324, 0.5952380952380952, 'x[0] <= 63.225\nsquared_error = 0.001\nsamples = 2\nvalue = 2.215'),
#  Text(0.6048801838275523, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.241'),
#  Text(0.6118831381989277, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.19'),
#  Text(0.6153846153846154, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.094'),
#  Text(0.6258890469416786, 0.6428571428571429, 'x[0] <= 64.139\nsquared_error = 0.006\nsamples = 3\nvalue = 2.262'),
#  Text(0.6223875697559909, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.367'),
#  Text(0.6293905241273662, 0.5952380952380952, 'x[0] <= 64.42\nsquared_error = 0.0\nsamples = 2\nvalue = 2.209'),
#  Text(0.6258890469416786, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.197'),
#  Text(0.6328920013130539, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.221'),
#  Text(0.6258890469416786, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.056'),
#  Text(0.6574023416128679, 0.7380952380952381, 'x[0] <= 67.833\nsquared_error = 0.005\nsamples = 13\nvalue = 2.274'),
#  Text(0.6468979100558048, 0.6904761904761905, 'x[0] <= 65.867\nsquared_error = 0.003\nsamples = 7\nvalue = 2.327'),
#  Text(0.6398949556844293, 0.6428571428571429, 'x[0] <= 65.364\nsquared_error = 0.0\nsamples = 2\nvalue = 2.384'),
#  Text(0.6363934784987416, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.398'),
#  Text(0.643396432870117, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.371'),
#  Text(0.6539008644271802, 0.6428571428571429, 'x[0] <= 67.333\nsquared_error = 0.002\nsamples = 5\nvalue = 2.304'),
#  Text(0.6503993872414925, 0.5952380952380952, 'x[0] <= 66.832\nsquared_error = 0.0\nsamples = 4\nvalue = 2.282'),
#  Text(0.6468979100558048, 0.5476190476190477, 'x[0] <= 66.336\nsquared_error = 0.0\nsamples = 3\nvalue = 2.285'),
#  Text(0.643396432870117, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.279'),
#  Text(0.6503993872414925, 0.5, 'x[0] <= 66.573\nsquared_error = 0.0\nsamples = 2\nvalue = 2.288'),
#  Text(0.6468979100558048, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.29'),
#  Text(0.6539008644271802, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 2.287'),
#  Text(0.6539008644271802, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.272'),
#  Text(0.6574023416128679, 0.5952380952380952, 'squared_error = -0.0\nsamples = 1\nvalue = 2.393'),
#  Text(0.6679067731699311, 0.6904761904761905, 'x[0] <= 67.914\nsquared_error = 0.001\nsamples = 6\nvalue = 2.212'),
#  Text(0.6644052959842434, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.155'),
#  Text(0.6714082503556188, 0.6428571428571429, 'x[0] <= 68.746\nsquared_error = 0.0\nsamples = 5\nvalue = 2.223'),
#  Text(0.6644052959842434, 0.5952380952380952, 'x[0] <= 68.17\nsquared_error = 0.0\nsamples = 3\nvalue = 2.218'),
#  Text(0.6609038187985556, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.224'),
#  Text(0.6679067731699311, 0.5476190476190477, 'x[0] <= 68.508\nsquared_error = 0.0\nsamples = 2\nvalue = 2.215'),
#  Text(0.6644052959842434, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.208'),
#  Text(0.6714082503556188, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 2.221'),
#  Text(0.6784112047269942, 0.5952380952380952, 'x[0] <= 68.906\nsquared_error = 0.0\nsamples = 2\nvalue = 2.231'),
#  Text(0.6749097275413065, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.232'),
#  Text(0.681912681912682, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.229'),
#  Text(0.8133651110624794, 0.7857142857142857, 'x[0] <= 86.486\nsquared_error = 0.019\nsamples = 63\nvalue = 2.497'),
#  Text(0.7361513841777, 0.7380952380952381, 'x[0] <= 74.414\nsquared_error = 0.016\nsamples = 52\nvalue = 2.518'),
#  Text(0.7134259765838713, 0.6904761904761905, 'x[0] <= 73.408\nsquared_error = 0.01\nsamples = 13\nvalue = 2.453'),
#  Text(0.7029215450268081, 0.6428571428571429, 'x[0] <= 70.564\nsquared_error = 0.005\nsamples = 10\nvalue = 2.498'),
#  Text(0.692417113469745, 0.5952380952380952, 'x[0] <= 69.662\nsquared_error = 0.001\nsamples = 3\nvalue = 2.414'),
#  Text(0.6889156362840574, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.385'),
#  Text(0.6959185906554327, 0.5476190476190477, 'x[0] <= 70.011\nsquared_error = 0.0\nsamples = 2\nvalue = 2.429'),
#  Text(0.692417113469745, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.415'),
#  Text(0.6994200678411204, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.444'),
#  Text(0.7134259765838713, 0.5952380952380952, 'x[0] <= 73.132\nsquared_error = 0.003\nsamples = 7\nvalue = 2.534'),
#  Text(0.7099244993981836, 0.5476190476190477, 'x[0] <= 72.627\nsquared_error = 0.003\nsamples = 6\nvalue = 2.527'),
#  Text(0.7064230222124959, 0.5, 'x[0] <= 72.279\nsquared_error = 0.002\nsamples = 5\nvalue = 2.541'),
#  Text(0.7029215450268081, 0.4523809523809524, 'x[0] <= 72.209\nsquared_error = 0.0\nsamples = 4\nvalue = 2.519'),
#  Text(0.6994200678411204, 0.40476190476190477, 'x[0] <= 71.574\nsquared_error = 0.0\nsamples = 3\nvalue = 2.526'),
#  Text(0.6959185906554327, 0.35714285714285715, 'x[0] <= 70.958\nsquared_error = 0.0\nsamples = 2\nvalue = 2.521'),
#  Text(0.692417113469745, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.529'),
#  Text(0.6994200678411204, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.513'),
#  Text(0.7029215450268081, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 2.536'),
#  Text(0.7064230222124959, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.499'),
#  Text(0.7099244993981836, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 2.627'),
#  Text(0.7134259765838713, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 2.457'),
#  Text(0.716927453769559, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.575'),
#  Text(0.7239304081409345, 0.6428571428571429, 'x[0] <= 73.74\nsquared_error = 0.0\nsamples = 3\nvalue = 2.305'),
#  Text(0.7204289309552467, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.299'),
#  Text(0.7274318853266222, 0.5952380952380952, 'x[0] <= 74.006\nsquared_error = 0.0\nsamples = 2\nvalue = 2.308'),
#  Text(0.7239304081409345, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.307'),
#  Text(0.7309333625123099, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.31'),
#  Text(0.7588767917715286, 0.6904761904761905, 'x[0] <= 75.176\nsquared_error = 0.016\nsamples = 39\nvalue = 2.539'),
#  Text(0.7379363168836853, 0.6428571428571429, 'x[0] <= 74.813\nsquared_error = 0.003\nsamples = 3\nvalue = 2.697'),
#  Text(0.7344348396979976, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.627'),
#  Text(0.741437794069373, 0.5952380952380952, 'x[0] <= 74.884\nsquared_error = 0.0\nsamples = 2\nvalue = 2.732'),
#  Text(0.7379363168836853, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.745'),
#  Text(0.7449392712550608, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.719'),
#  Text(0.7798172666593719, 0.6428571428571429, 'x[0] <= 75.785\nsquared_error = 0.015\nsamples = 36\nvalue = 2.526'),
#  Text(0.7554437028121239, 0.5952380952380952, 'x[0] <= 75.494\nsquared_error = 0.0\nsamples = 2\nvalue = 2.392'),
#  Text(0.7519422256264362, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.384'),
#  Text(0.7589451799978115, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.399'),
#  Text(0.80419083050662, 0.5952380952380952, 'x[0] <= 84.196\nsquared_error = 0.014\nsamples = 34\nvalue = 2.534'),
#  Text(0.765948134369187, 0.5476190476190477, 'x[0] <= 76.034\nsquared_error = 0.012\nsamples = 28\nvalue = 2.547'),
#  Text(0.7513951198161725, 0.5, 'x[0] <= 76.023\nsquared_error = 0.001\nsamples = 3\nvalue = 2.608'),
#  Text(0.7478936426304847, 0.4523809523809524, 'x[0] <= 76.002\nsquared_error = 0.001\nsamples = 2\nvalue = 2.587'),
#  Text(0.744392165444797, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.616'),
#  Text(0.7513951198161725, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.558'),
#  Text(0.7548965970018602, 0.4523809523809524, 'squared_error = -0.0\nsamples = 1\nvalue = 2.649'),
#  Text(0.7805011489222016, 0.5, 'x[0] <= 76.771\nsquared_error = 0.013\nsamples = 25\nvalue = 2.54'),
#  Text(0.7618995513732356, 0.4523809523809524, 'x[0] <= 76.433\nsquared_error = 0.002\nsamples = 3\nvalue = 2.42'),
#  Text(0.7583980741875479, 0.40476190476190477, 'x[0] <= 76.162\nsquared_error = 0.001\nsamples = 2\nvalue = 2.447'),
#  Text(0.7548965970018602, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 2.414'),
#  Text(0.7618995513732356, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 2.48'),
#  Text(0.7654010285589233, 0.40476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.367'),
#  Text(0.7991027464711675, 0.4523809523809524, 'x[0] <= 79.146\nsquared_error = 0.012\nsamples = 22\nvalue = 2.556'),
#  Text(0.7759054601159864, 0.40476190476190477, 'x[0] <= 77.106\nsquared_error = 0.005\nsamples = 7\nvalue = 2.595'),
#  Text(0.768902505744611, 0.35714285714285715, 'x[0] <= 76.984\nsquared_error = 0.001\nsamples = 2\nvalue = 2.542'),
#  Text(0.7654010285589233, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.568'),
#  Text(0.7724039829302988, 0.30952380952380953, 'squared_error = -0.0\nsamples = 1\nvalue = 2.515'),
#  Text(0.7829084144873618, 0.35714285714285715, 'x[0] <= 77.239\nsquared_error = 0.005\nsamples = 5\nvalue = 2.617'),
#  Text(0.7794069373016741, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.704'),
#  Text(0.7864098916730495, 0.30952380952380953, 'x[0] <= 78.469\nsquared_error = 0.004\nsamples = 4\nvalue = 2.595'),
#  Text(0.7829084144873618, 0.2619047619047619, 'x[0] <= 78.211\nsquared_error = 0.004\nsamples = 3\nvalue = 2.576'),
#  Text(0.7794069373016741, 0.21428571428571427, 'x[0] <= 77.618\nsquared_error = 0.003\nsamples = 2\nvalue = 2.612'),
#  Text(0.7759054601159864, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.561'),
#  Text(0.7829084144873618, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.664'),
#  Text(0.7864098916730495, 0.21428571428571427, 'squared_error = -0.0\nsamples = 1\nvalue = 2.502'),
#  Text(0.7899113688587373, 0.2619047619047619, 'squared_error = -0.0\nsamples = 1\nvalue = 2.654'),
#  Text(0.8223000328263487, 0.40476190476190477, 'x[0] <= 80.469\nsquared_error = 0.014\nsamples = 15\nvalue = 2.538'),
#  Text(0.8074187547871758, 0.35714285714285715, 'x[0] <= 79.967\nsquared_error = 0.012\nsamples = 5\nvalue = 2.47'),
#  Text(0.8004158004158004, 0.30952380952380953, 'x[0] <= 79.852\nsquared_error = 0.016\nsamples = 2\nvalue = 2.545'),
#  Text(0.7969143232301127, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 2.418'),
#  Text(0.8039172776014881, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 2.672'),
#  Text(0.8144217091585513, 0.30952380952380953, 'x[0] <= 80.294\nsquared_error = 0.004\nsamples = 3\nvalue = 2.421'),
#  Text(0.8109202319728636, 0.2619047619047619, 'x[0] <= 80.144\nsquared_error = 0.004\nsamples = 2\nvalue = 2.444'),
#  Text(0.8074187547871758, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 2.383'),
#  Text(0.8144217091585513, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 2.505'),
#  Text(0.817923186344239, 0.2619047619047619, 'squared_error = -0.0\nsamples = 1\nvalue = 2.374'),
#  Text(0.8371813108655214, 0.35714285714285715, 'x[0] <= 81.318\nsquared_error = 0.012\nsamples = 10\nvalue = 2.572'),
#  Text(0.8284276179013021, 0.30952380952380953, 'x[0] <= 80.781\nsquared_error = 0.003\nsamples = 2\nvalue = 2.69'),
#  Text(0.8249261407156144, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 2.747'),
#  Text(0.8319290950869899, 0.2619047619047619, 'squared_error = 0.0\nsamples = 1\nvalue = 2.633'),
#  Text(0.8459350038297406, 0.30952380952380953, 'x[0] <= 82.077\nsquared_error = 0.01\nsamples = 8\nvalue = 2.543'),
#  Text(0.8389320494583653, 0.2619047619047619, 'x[0] <= 81.784\nsquared_error = 0.0\nsamples = 2\nvalue = 2.447'),
#  Text(0.8354305722726776, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 2.455'),
#  Text(0.8424335266440529, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 2.439'),
#  Text(0.8529379582011161, 0.2619047619047619, 'x[0] <= 82.436\nsquared_error = 0.009\nsamples = 6\nvalue = 2.575'),
#  Text(0.8494364810154283, 0.21428571428571427, 'squared_error = 0.0\nsamples = 1\nvalue = 2.701'),
#  Text(0.8564394353868038, 0.21428571428571427, 'x[0] <= 82.642\nsquared_error = 0.007\nsamples = 5\nvalue = 2.549'),
#  Text(0.8529379582011161, 0.16666666666666666, 'squared_error = 0.0\nsamples = 1\nvalue = 2.437'),
#  Text(0.8599409125724915, 0.16666666666666666, 'x[0] <= 83.954\nsquared_error = 0.005\nsamples = 4\nvalue = 2.577'),
#  Text(0.8564394353868038, 0.11904761904761904, 'x[0] <= 83.447\nsquared_error = 0.006\nsamples = 3\nvalue = 2.558'),
#  Text(0.8529379582011161, 0.07142857142857142, 'x[0] <= 82.884\nsquared_error = 0.001\nsamples = 2\nvalue = 2.609'),
#  Text(0.8494364810154283, 0.023809523809523808, 'squared_error = 0.0\nsamples = 1\nvalue = 2.584'),
#  Text(0.8564394353868038, 0.023809523809523808, 'squared_error = 0.0\nsamples = 1\nvalue = 2.635'),
#  Text(0.8599409125724915, 0.07142857142857142, 'squared_error = 0.0\nsamples = 1\nvalue = 2.457'),
#  Text(0.8634423897581792, 0.11904761904761904, 'squared_error = -0.0\nsamples = 1\nvalue = 2.634'),
#  Text(0.8424335266440529, 0.5476190476190477, 'x[0] <= 84.981\nsquared_error = 0.02\nsamples = 6\nvalue = 2.472'),
#  Text(0.8389320494583653, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.316'),
#  Text(0.8459350038297406, 0.5, 'x[0] <= 85.754\nsquared_error = 0.019\nsamples = 5\nvalue = 2.503'),
#  Text(0.8424335266440529, 0.4523809523809524, 'squared_error = 0.0\nsamples = 1\nvalue = 2.652'),
#  Text(0.8494364810154283, 0.4523809523809524, 'x[0] <= 86.014\nsquared_error = 0.016\nsamples = 4\nvalue = 2.466'),
#  Text(0.8459350038297406, 0.40476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.249'),
#  Text(0.8529379582011161, 0.40476190476190477, 'x[0] <= 86.324\nsquared_error = 0.001\nsamples = 3\nvalue = 2.539'),
#  Text(0.8494364810154283, 0.35714285714285715, 'squared_error = 0.0\nsamples = 1\nvalue = 2.579'),
#  Text(0.8564394353868038, 0.35714285714285715, 'x[0] <= 86.464\nsquared_error = 0.0\nsamples = 2\nvalue = 2.518'),
#  Text(0.8529379582011161, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.505'),
#  Text(0.8599409125724915, 0.30952380952380953, 'squared_error = 0.0\nsamples = 1\nvalue = 2.532'),
#  Text(0.890578837947259, 0.7380952380952381, 'x[0] <= 89.256\nsquared_error = 0.024\nsamples = 11\nvalue = 2.399'),
#  Text(0.8756975599080862, 0.6904761904761905, 'x[0] <= 88.84\nsquared_error = 0.032\nsamples = 7\nvalue = 2.353'),
#  Text(0.8669438669438669, 0.6428571428571429, 'x[0] <= 88.548\nsquared_error = 0.023\nsamples = 5\nvalue = 2.431'),
#  Text(0.8599409125724915, 0.5952380952380952, 'x[0] <= 87.796\nsquared_error = 0.017\nsamples = 3\nvalue = 2.341'),
#  Text(0.8564394353868038, 0.5476190476190477, 'x[0] <= 86.801\nsquared_error = 0.002\nsamples = 2\nvalue = 2.43'),
#  Text(0.8529379582011161, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.38'),
#  Text(0.8599409125724915, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.479'),
#  Text(0.8634423897581792, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.165'),
#  Text(0.8739468213152424, 0.5952380952380952, 'x[0] <= 88.652\nsquared_error = 0.0\nsamples = 2\nvalue = 2.567'),
#  Text(0.8704453441295547, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.565'),
#  Text(0.8774482985009301, 0.5476190476190477, 'squared_error = -0.0\nsamples = 1\nvalue = 2.569'),
#  Text(0.8844512528723055, 0.6428571428571429, 'x[0] <= 89.115\nsquared_error = 0.0\nsamples = 2\nvalue = 2.157'),
#  Text(0.8809497756866178, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.144'),
#  Text(0.8879527300579932, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.171'),
#  Text(0.9054601159864317, 0.6904761904761905, 'x[0] <= 89.561\nsquared_error = 0.0\nsamples = 4\nvalue = 2.48'),
#  Text(0.8984571616150564, 0.6428571428571429, 'x[0] <= 89.376\nsquared_error = 0.0\nsamples = 2\nvalue = 2.466'),
#  Text(0.8949556844293687, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.458'),
#  Text(0.9019586388007441, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.474'),
#  Text(0.9124630703578072, 0.6428571428571429, 'x[0] <= 89.858\nsquared_error = 0.0\nsamples = 2\nvalue = 2.495'),
#  Text(0.9089615931721194, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.5'),
#  Text(0.9159645475434949, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.49'),
#  Text(0.9518546886967939, 0.8333333333333334, 'x[0] <= 93.346\nsquared_error = 0.015\nsamples = 21\nvalue = 2.135'),
#  Text(0.926468979100558, 0.7857142857142857, 'x[0] <= 90.523\nsquared_error = 0.006\nsamples = 10\nvalue = 2.23'),
#  Text(0.9159645475434949, 0.7380952380952381, 'x[0] <= 90.462\nsquared_error = 0.0\nsamples = 2\nvalue = 2.143'),
#  Text(0.9124630703578072, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.141'),
#  Text(0.9194660247291826, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 2.145'),
#  Text(0.9369734106576212, 0.7380952380952381, 'x[0] <= 91.505\nsquared_error = 0.005\nsamples = 8\nvalue = 2.252'),
#  Text(0.926468979100558, 0.6904761904761905, 'x[0] <= 90.564\nsquared_error = 0.002\nsamples = 3\nvalue = 2.326'),
#  Text(0.9229675019148703, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.267'),
#  Text(0.9299704562862458, 0.6428571428571429, 'x[0] <= 90.851\nsquared_error = 0.0\nsamples = 2\nvalue = 2.356'),
#  Text(0.926468979100558, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.342'),
#  Text(0.9334719334719335, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.37'),
#  Text(0.9474778422146843, 0.6904761904761905, 'x[0] <= 93.266\nsquared_error = 0.001\nsamples = 5\nvalue = 2.207'),
#  Text(0.9439763650289966, 0.6428571428571429, 'x[0] <= 92.634\nsquared_error = 0.0\nsamples = 4\nvalue = 2.222'),
#  Text(0.9404748878433089, 0.5952380952380952, 'x[0] <= 92.025\nsquared_error = 0.0\nsamples = 3\nvalue = 2.217'),
#  Text(0.9369734106576212, 0.5476190476190477, 'x[0] <= 91.963\nsquared_error = 0.0\nsamples = 2\nvalue = 2.228'),
#  Text(0.9334719334719335, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.217'),
#  Text(0.9404748878433089, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 2.24'),
#  Text(0.9439763650289966, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.194'),
#  Text(0.9474778422146843, 0.5952380952380952, 'squared_error = 0.0\nsamples = 1\nvalue = 2.237'),
#  Text(0.9509793194003721, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.148'),
#  Text(0.9772403982930299, 0.7857142857142857, 'x[0] <= 95.965\nsquared_error = 0.008\nsamples = 11\nvalue = 2.048'),
#  Text(0.9684867053288105, 0.7380952380952381, 'x[0] <= 95.603\nsquared_error = 0.008\nsamples = 7\nvalue = 2.035'),
#  Text(0.9649852281431229, 0.6904761904761905, 'x[0] <= 95.29\nsquared_error = 0.005\nsamples = 6\nvalue = 2.061'),
#  Text(0.9614837509574352, 0.6428571428571429, 'x[0] <= 94.134\nsquared_error = 0.001\nsamples = 5\nvalue = 2.032'),
#  Text(0.9544807965860598, 0.5952380952380952, 'x[0] <= 93.702\nsquared_error = 0.0\nsamples = 2\nvalue = 2.065'),
#  Text(0.9509793194003721, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.051'),
#  Text(0.9579822737717475, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.08'),
#  Text(0.9684867053288105, 0.5952380952380952, 'x[0] <= 95.129\nsquared_error = 0.001\nsamples = 3\nvalue = 2.01'),
#  Text(0.9649852281431229, 0.5476190476190477, 'x[0] <= 94.622\nsquared_error = 0.0\nsamples = 2\nvalue = 1.987'),
#  Text(0.9614837509574352, 0.5, 'squared_error = 0.0\nsamples = 1\nvalue = 1.995'),
#  Text(0.9684867053288105, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 1.979'),
#  Text(0.9719881825144983, 0.5476190476190477, 'squared_error = 0.0\nsamples = 1\nvalue = 2.056'),
#  Text(0.9684867053288105, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.203'),
#  Text(0.9719881825144983, 0.6904761904761905, 'squared_error = 0.0\nsamples = 1\nvalue = 1.882'),
#  Text(0.9859940912572491, 0.7380952380952381, 'x[0] <= 96.935\nsquared_error = 0.007\nsamples = 4\nvalue = 2.072'),
#  Text(0.9789911368858737, 0.6904761904761905, 'x[0] <= 96.245\nsquared_error = 0.001\nsamples = 2\nvalue = 2.129'),
#  Text(0.975489659700186, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.102'),
#  Text(0.9824926140715614, 0.6428571428571429, 'squared_error = -0.0\nsamples = 1\nvalue = 2.157'),
#  Text(0.9929970456286246, 0.6904761904761905, 'x[0] <= 98.123\nsquared_error = 0.006\nsamples = 2\nvalue = 2.014'),
#  Text(0.9894955684429368, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 1.939'),
#  Text(0.9964985228143123, 0.6428571428571429, 'squared_error = 0.0\nsamples = 1\nvalue = 2.089')]

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C':[0.01,0.1,1,5,10,100,1000],'gamma':['auto','scale']}
svr = SVR()

# %%
grid = GridSearchCV(svr,param_grid)

# %%
run_model(grid,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.12646999302046696

# %%
grid.best_estimator_
# Out:
# SVR(C=1000)

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# help(RandomForestRegressor)

# %%
trees = [10,50,100]

for n in trees:    
    model = RandomForestRegressor(n_estimators=n)
    run_model(model,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.13751561581411925
# RMSE : 0.13181939953833333
# RMSE : 0.13745423081827016

# %% [markdown]
# ## Gradient Boosting
#
# We will cover this in more detail in next section.

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
# help(GradientBoostingRegressor)

# %%
model = GradientBoostingRegressor()
run_model(model,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.13294148649584667

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
model = GradientBoostingRegressor()

run_model(model,X_train,y_train,X_test,y_test)
# Out:
# RMSE : 0.13294148649584667
